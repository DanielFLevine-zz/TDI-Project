# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
shroud_chat = open(r'C:\Users\Daniel\Desktop\Python Projects\Twitch_data\ICWSM19_data\shroud.pkl','rb')

df_shroud = pickle.load(shroud_chat)

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
text = " ".join(comment for comment in df_shroud['body'].iloc[0:10000])

wordcloud = WordCloud(width = 2000, height = 2000, 
                background_color ='white').generate(text)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df1 = df_shroud[df_shroud['body'].str.contains("pubg")]
print(df1)
# Out:
#                                                       body channel_id  \
# 22       playing pubg while watching a twitch stream on...   37402112
# 124       Get j9 back on pubg!!!! He will love this update   37402112
# 342               shroud is a pubg god thats who shroud is   37402112
# 831                              New pubg image on twitch?   37402112
# 863                                he is the ninja of pubg   37402112
# ...                                                    ...        ...
# 3971422                                          some pubg   37402112
# 3971458                                          play pubg   37402112
# 3971553                                           pubg boi   37402112
# 3971555                                     go pubg shroud   37402112
# 3971596                                            go pubg   37402112
#
#         commenter_id commenter_type                created_at  \
# 22         141580890           user  2018-06-22T19:44:39.651Z
# 124        121013898           user  2018-06-22T19:45:29.208Z
# 342         69130976           user  2018-06-22T19:46:31.694Z
# 831        175002409           user  2018-06-22T19:48:56.247Z
# 863        121090842           user  2018-06-22T19:49:06.038Z
# ...              ...            ...                       ...
# 3971422    119265194           user   2018-03-19T02:58:18.62Z
# 3971458    202022921           user  2018-03-19T02:59:23.776Z
# 3971553     87327462           user  2018-03-19T03:02:14.285Z
# 3971555    159892373           user  2018-03-19T03:02:19.204Z
# 3971596    197621362           user  2018-03-19T03:03:47.164Z
#
#                                                  fragments     offset  \
# 22       [{'text': 'playing pubg while watching a twitc...     17.851
# 124      [{'text': 'Get j9 back on pubg!!!! He will lov...     67.408
# 342      [{'text': 'shroud is a pubg god thats who shro...    129.894
# 831                [{'text': 'New pubg image on twitch?'}]    274.447
# 863                  [{'text': 'he is the ninja of pubg'}]    284.238
# ...                                                    ...        ...
# 3971422                            [{'text': 'some pubg'}]  21753.820
# 3971458                            [{'text': 'play pubg'}]  21818.976
# 3971553                             [{'text': 'pubg boi'}]  21989.485
# 3971555                       [{'text': 'go pubg shroud'}]  21994.404
# 3971596                              [{'text': 'go pubg'}]  22082.364
#
#                        updated_at   video_id
# 22       2018-06-22T19:44:39.651Z  276329573
# 124      2018-06-22T19:45:29.208Z  276329573
# 342      2018-06-22T19:46:31.694Z  276329573
# 831      2018-06-22T19:48:56.247Z  276329573
# 863      2018-06-22T19:49:06.038Z  276329573
# ...                           ...        ...
# 3971422   2018-03-19T02:58:18.62Z  240248622
# 3971458  2018-03-19T02:59:23.776Z  240248622
# 3971553  2018-03-19T03:02:14.285Z  240248622
# 3971555  2018-03-19T03:02:19.204Z  240248622
# 3971596  2018-03-19T03:03:47.164Z  240248622
#
# [20762 rows x 9 columns]
